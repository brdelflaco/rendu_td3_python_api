# %% [markdown]
# # Python with APIs
# Exchanges via HTTP using `requests` package

# %%
import requests

# %% [markdown]
# ## Example

# %% [markdown]
# ### Agify API

# %% [markdown]
# Example route for Agify API

# %%
agify_dan = "https://api.agify.io/?name=dan"

# %% [markdown]
# Extract response

# %%
# Run a GET request
agify_answer = requests.get(agify_dan)
agify_answer_txt = agify_answer.text
agify_answer_json = agify_answer.json()

print(f"Answer status_code: {agify_answer}")

print(type(agify_answer_txt))
print(type(agify_answer_json))

print(agify_answer_txt)
print(agify_answer_json)
# Out:
# Answer status_code: <Response [200]>
# <class 'str'>
# <class 'dict'>
# {"count":67782,"name":"dan","age":66}
# {'count': 67782, 'name': 'dan', 'age': 66}

# %% [markdown]
# ## Introductory Exercises

# %%
# Exercise 1
# Write a script that asks the user for their first name
# and responds with a personalized message
# using the agify API

# https://api.agify.io/?name=YOUR_NAME
# Example response: {"name":"YOUR_NAME","age":30,"count":12345}

YOUR_NAME = input("Entrez votre nom : ")
agify = f"https://api.agify.io/?name={YOUR_NAME}"

agify_answer = requests.get(agify)
agify_answer_json = agify_answer.json()

# Accéder et imprimer chaque valeur séparément dans l'ordre souhaité
print(f"name: {agify_answer_json['name']}, age: {agify_answer_json['age']}, count: {agify_answer_json['count']}")
# Out:
# Entrez votre nom : Alex
# name: Alex, age: 47, count: 411442

# %%
# Exercise 2
# Write a script that asks the user for their first name
# and responds with a personalized message
# using the genderize API
# https://api.genderize.io/?name=YOUR_NAME

YOUR_NAME = input("Entrez votre prénom : ")
genderize_url = "https://api.genderize.io/?name=" + YOUR_NAME

reponse_genderize = requests.get(genderize_url)
reponse_genderize_json = reponse_genderize.json()

if 'gender' in reponse_genderize_json and reponse_genderize_json['gender'] is not None:
    genre = reponse_genderize_json['gender']
    print("Bonjour " + YOUR_NAME + ", d'après votre prénom, je prédis que votre genre est : " + genre)
else:
    print("Désolé, je ne peux pas prédire le genre pour le prénom " + YOUR_NAME)
# Out:
# Entrez votre prénom : Alex
# Bonjour Alex, d'après votre prénom, je prédis que votre genre est : male

# %%
# Exercise 3
# Write a script that asks the user for their first name
# and responds with a personalized message
# using the nationalize API
# https://api.nationalize.io/?name=YOUR_NAME

YOUR_NAME = input("Entrez votre prénom : ")

nationalize_url = "https://api.nationalize.io/?name=" + YOUR_NAME

reponse_nationalize = requests.get(nationalize_url)
reponse_nationalize_json = reponse_nationalize.json()

if 'country' in reponse_nationalize_json and reponse_nationalize_json['country']:
    pays = reponse_nationalize_json['country'][0]['country_id']
    proba = reponse_nationalize_json['country'][0]['probability'] * 100
    print(f"Bonjour {YOUR_NAME}, d'après votre prénom, je prédis que vous êtes de nationalité {pays} avec une probabilité de {proba:.2f}%.")
else:
    print(f"Désolé, je ne peux pas prédire la nationalité pour le prénom {YOUR_NAME}.")
# Out:
# Entrez votre prénom : Alex
# Bonjour Alex, d'après votre prénom, je prédis que vous êtes de nationalité CZ avec une probabilité de 41.65%.

# %%
# Exercise 3.1
# Parsing the response from the nationalize API
# Get the most probable country and its percentage
# Example response: {"name":"YOUR_NAME","country":[{"country_id":"FR","probability":0.75},{"country_id":"BE","probability":0.25}]}
# Hint: use the max() function with a lambda function
# https://docs.python.org/3/library/functions.html#max
# https://docs.python.org/3/tutorial/controlflow.html#lambda-expressions

import json  # Importe le module json pour la conversion en chaîne JSON

YOUR_NAME = input("Entrez votre prénom : ")
def nationalites_probables_json(YOUR_NAME):
    url = f"https://api.nationalize.io/?name={YOUR_NAME}"
    reponse = requests.get(url)
    if reponse.status_code == 200:
        donnees = reponse.json()
        if donnees['country']:
            sortie = {
                "name": YOUR_NAME,
                "country": [
                    {"country_id": pays['country_id'], "probability": round(pays['probability'], 2)}
                    for pays in donnees['country']
                ]
            }
            sortie_json = json.dumps(sortie, indent=4)
            print(sortie_json)
        else:
            print(f"Aucune nationalité trouvée pour le prénom {YOUR_NAME}.")
    else:
        print("Erreur lors de la requête à l'API Nationalize.")

nationalites_probables_json(YOUR_NAME)
# Out:
# Entrez votre prénom : Alex
# {
#     "name": "Alex",
#     "country": [
#         {
#             "country_id": "CZ",
#             "probability": 0.42
#         },
#         {
#             "country_id": "RO",
#             "probability": 0.09
#         },
#         {
#             "country_id": "CN",
#             "probability": 0.05
#         },
#         {
#             "country_id": "UG",
#             "probability": 0.04
#         },
#         {
#             "country_id": "NG",
#             "probability": 0.02
#         }
#     ]
# }

# %%
# Exercise 4
# Use BoredAPI : https://www.boredapi.com/
# Documentation : https://www.boredapi.com/documentation
# 1. Write a script that generates random activities
# 2. Write a script that generates random activities
# 3. Write a script that generates random activities for 4 participants
# 4. Write a script that generates random activities for 4 participants and of type "recreational"
# 5. Write a script that generates random activities for 2 participants and that does not require equipment

#1 et #2
def activite_aleatoire():
    url = "https://www.boredapi.com/api/activity"
    reponse = requests.get(url)
    if reponse.status_code == 200:
        activite = reponse.json()['activity']
        print(f"Activité possible : {activite}")
    else:
        print("Impossible de récupérer une activité.")

activite_aleatoire()
activite_aleatoire()

#3
def activite_a_4():
    url = "https://www.boredapi.com/api/activity?participants=4"
    reponse = requests.get(url)
    if reponse.status_code == 200:
        activite = reponse.json()['activity']
        print(f"Activité à 4 : {activite}")
    else:
        print("Impossible de récupérer une activité pour 4 participants.")

activite_a_4()

#4
import requests

def activite_a_4_recreative():
    url = "https://www.boredapi.com/api/activity?participants=4&type=recreational"
    reponse = requests.get(url)
    if reponse.status_code == 200:
        activite = reponse.json()['activity']
        print(f"Activité récréative à 4 : {activite}")
    else:
        print("Impossible de récupérer une activité récréative pour 4 participants.")

activite_a_4_recreative()

#5
def activite_a_2():
    url = "https://www.boredapi.com/api/activity?participants=2"
    reponse = requests.get(url)
    if reponse.status_code == 200:
        activite = reponse.json()['activity']
        print(f"Activité à 2 : {activite}")
    else:
        print("Impossible de récupérer une activité pour 2 participants.")

activite_a_2()
# Out:
# Activité possible : Start a family tree
# Activité possible : Go to a local thrift shop
# Activité à 4 : Go see a movie in theaters with a few friends
# Activité récréative à 4 : Go see a Broadway production
# Activité à 2 : Catch up with a friend over a lunch date

# %% [markdown]
# ## Intermediate exercises

# %%
# OpenDomesday
# https://opendomesday.org/api/

# Exercise 1
# Write a script that displays all the counties
# using the OpenDomesday API.

def afficher_comtes():
    url = "https://opendomesday.org/api/1.0/county/"
    reponse = requests.get(url)
    if reponse.status_code == 200:
        comtes = reponse.json()
        for comte in comtes:
            print(comte['name'])
    else:
        print("Impossible de récupérer les comtés.")

afficher_comtes()
# Out:
# Kent
# Sussex
# Surrey
# Hampshire
# Berkshire
# Wiltshire
# Dorset
# Somerset
# Devon
# Cornwall
# Middlesex
# Hertfordshire
# Buckinghamshire
# Gloucestershire
# Oxfordshire
# Worcestershire
# Herefordshire
# Cambridgeshire
# Huntingdonshire
# Bedfordshire
# Northamptonshire
# Leicestershire
# Warwickshire
# Staffordshire
# Shropshire
# Cheshire
# Derbyshire
# Nottinghamshire
# Rutland
# Yorkshire
# Lincolnshire
# Claims: YB
# Claims: YC
# Claims: LC
# Claims: HC
# Claims: YS
# Essex
# Norfolk
# Suffolk
# Lancashire

# %%
# Exercise 2
# Write a script that displays the information
# of the county "Derbyshire".

def informations_derbyshire():
    url = "https://opendomesday.org/api/1.0/county/"
    reponse = requests.get(url)
    if reponse.status_code == 200:
        comtes = reponse.json()
        derbyshire = next((comte for comte in comtes if comte['name'] == 'Derbyshire'), None)
        if derbyshire:
            print(f"Informations pour Derbyshire:")
            for cle, valeur in derbyshire.items():
                print(f"{cle}: {valeur}")
        else:
            print("Derbyshire n'a pas été trouvé dans la liste des comtés.")
    else:
        print("Impossible de récupérer les informations des comtés.")

informations_derbyshire()
# Out:
# Informations pour Derbyshire:
# id: dby
# name: Derbyshire
# name_slug: derbyshire
# places_in_county: [{'id': 1036}, {'id': 2558}, {'id': 3016}, {'id': 4791}, {'id': 6093}, {'id': 8701}, {'id': 8951}, {'id': 9101}, {'id': 11441}, {'id': 10771}, {'id': 16116}, {'id': 20861}, {'id': 22251}, {'id': 22571}, {'id': 22611}, {'id': 24741}, {'id': 25536}, {'id': 19061}, {'id': 30246}, {'id': 31896}, {'id': 32521}, {'id': 32981}, {'id': 33916}, {'id': 41346}, {'id': 41788}, {'id': 41801}, {'id': 45821}, {'id': 47401}, {'id': 47411}, {'id': 52361}, {'id': 52596}, {'id': 53901}, {'id': 54446}, {'id': 54646}, {'id': 55736}, {'id': 56786}, {'id': 57061}, {'id': 60236}, {'id': 60351}, {'id': 60816}, {'id': 63606}, {'id': 65368}, {'id': 73221}, {'id': 73731}, {'id': 73741}, {'id': 91}, {'id': 2623}, {'id': 3011}, {'id': 3941}, {'id': 4046}, {'id': 5016}, {'id': 5676}, {'id': 7111}, {'id': 7116}, {'id': 7451}, {'id': 9056}, {'id': 10981}, {'id': 11656}, {'id': 11941}, {'id': 12751}, {'id': 13401}, {'id': 14081}, {'id': 14306}, {'id': 15306}, {'id': 15451}, {'id': 17386}, {'id': 17811}, {'id': 19611}, {'id': 22436}, {'id': 22476}, {'id': 24011}, {'id': 24306}, {'id': 25081}, {'id': 27521}, {'id': 33816}, {'id': 40056}, {'id': 28311}, {'id': 29846}, {'id': 30061}, {'id': 30211}, {'id': 30536}, {'id': 30571}, {'id': 20391}, {'id': 32571}, {'id': 33016}, {'id': 36211}, {'id': 37586}, {'id': 40057}, {'id': 39661}, {'id': 39956}, {'id': 40466}, {'id': 42799}, {'id': 43751}, {'id': 44321}, {'id': 28296}, {'id': 34241}, {'id': 46861}, {'id': 26971}, {'id': 2366}, {'id': 48026}, {'id': 49236}, {'id': 50311}, {'id': 52766}, {'id': 52791}, {'id': 55006}, {'id': 55131}, {'id': 58231}, {'id': 59051}, {'id': 42936}, {'id': 61396}, {'id': 62566}, {'id': 63721}, {'id': 67724}, {'id': 69701}, {'id': 72781}, {'id': 73841}
def sauvegarder_donnees(nom_fichier, donnees):
    """Sauvegarde les données dans un fichier JSON."""
    with open(nom_fichier, 'w') as fichier:
        json.dump(donnees, fichier, indent=4)

def charger_donnees(nom_fichier):
    """Charge les données à partir d'un fichier JSON, si le fichier existe."""
    try:
        with open(nom_fichier, 'r') as fichier:
            return json.load(fichier)
    except FileNotFoundError:
        return None

def recuperer_details_lieux(ids_lieux):
    """Récupère les détails des lieux à partir de leurs ID et les sauvegarde localement."""
    details_lieux = charger_donnees('details_lieux_derbyshire.json')
    if details_lieux is None:  # Si les données n'existent pas localement
        details_lieux = []
        for id_lieu in ids_lieux:
            url = f"https://opendomesday.org/api/1.0/place/{id_lieu}"
            reponse = requests.get(url)
            if reponse.status_code == 200:
                details_lieux.append(reponse.json())
            else:
                print(f"Impossible de récupérer les informations pour le lieu avec l'ID {id_lieu}.")
        # Sauvegarde les nouvelles données récupérées localement
        sauvegarder_donnees('details_lieux_derbyshire.json', details_lieux)
    return details_lieux

def afficher_details_lieux(ids_lieux):
    """Affiche les détails des lieux et vérifie les manoirs associés."""
    details_lieux = recuperer_details_lieux(ids_lieux)
    for lieu in details_lieux:
        print(f"Lieu ID: {lieu.get('id')} - Nom: {lieu.get('name', 'Inconnu')}")
        # Ici, on suppose que les informations des manoirs seraient incluses dans la réponse de l'API
        for manoir in lieu.get('manors', []):
            print(f"  Manoir: {manoir.get('name', 'Inconnu')} - Seigneur: {manoir.get('lord', 'Inconnu')}")

# Remplacez cette liste par les ID réels obtenus dans l'exercice précédent
afficher_details_lieux(ids_lieux_derbyshire)
# Out:
# Lieu ID: 1036 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 2558 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 3016 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 4791 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 6093 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 8701 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 8951 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 9101 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 11441 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 10771 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 16116 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 20861 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 22251 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 22571 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 22611 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 24741 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 25536 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 19061 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 30246 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 31896 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 32521 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 32981 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 33916 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 41346 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 41788 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 41801 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 45821 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 47401 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 47411 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 52361 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 52596 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 53901 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 54446 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 54646 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 55736 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 56786 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 57061 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 60236 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 60351 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 60816 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 63606 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 65368 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 73221 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 73731 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 73741 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 91 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 2623 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 3011 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 3941 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 4046 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 5016 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 5676 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 7111 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 7116 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 7451 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 9056 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 10981 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 11656 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 11941 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 12751 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 13401 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 14081 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 14306 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 15306 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 15451 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 17386 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 17811 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 19611 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 22436 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 22476 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 24011 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 24306 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 25081 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 27521 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 33816 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 40056 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 28311 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 29846 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 30061 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 30211 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 30536 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 30571 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 20391 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 32571 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 33016 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 36211 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 37586 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 40057 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 39661 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 39956 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 40466 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 42799 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 43751 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 44321 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 28296 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 34241 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 46861 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 26971 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 2366 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 48026 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 49236 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 50311 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 52766 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 52791 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 55006 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 55131 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 58231 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 59051 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 42936 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 61396 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 62566 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 63721 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 67724 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 69701 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 72781 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 73841 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 14941 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 20691 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 39371 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 42171 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 54526 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 46681 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 51241 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 64663 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 70526 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 1326 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 2401 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 3291 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 4001 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 8116 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 8831 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 9461 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 10196 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 12706 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 13281 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 22243 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 18184 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 18736 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 23231 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 6141 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 29236 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 29861 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 32336 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 33086 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 34446 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 35221 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 35041 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 37056 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 38231 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 40456 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 41344 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 42041 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 42046 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 42797 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 45553 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 46851 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 48266 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 49221 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 55881 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 56826 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 56941 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 61526 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 62731 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 63966 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 66911 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 68251 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 68481 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 68546 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 71226 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 71466 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 1136 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 1456 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 1596 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 2106 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 3163 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 4646 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 5396 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 8456 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 11731 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 14476 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 18001 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 19416 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 22741 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 23256 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 23731 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 24921 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 35046 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 35311 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 37656 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 39466 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 39566 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 40901 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 41658 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 42536 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 42741 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 44361 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 45893 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 47416 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 49901 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 50661 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 50806 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 54966 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 56216 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 58701 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 61046 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 63391 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 65696 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 69008 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 69081 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 70641 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 8956 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 9586 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 9611 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 13741 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 13806 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 16581 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 18621 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 19941 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 20101 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 21051 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 21326 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 28556 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 30666 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 31306 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 32361 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 33141 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 33376 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 34646 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 35946 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 37591 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 14686 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 22266 - Nom: Inconnu
# Lieu ID: 28563 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 22271 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 41006 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 41521 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 43091 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 43991 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 46746 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 48806 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 51961 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 52096 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 53806 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 53996 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 55576 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 55956 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 56606 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 56696 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 57526 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 58046 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 58196 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 66498 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 16166 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 18951 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 22546 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 58356 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 71196 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 986 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 2711 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 4311 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 4369 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 5791 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 7651 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 8016 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 8721 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 9218 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 10026 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 12721 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 14691 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 16356 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 3106 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 20756 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 21276 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 21301 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 22406 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 22766 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 23121 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 23598 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 26856 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 4367 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 27776 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 29076 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 29411 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 32576 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 32686 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 35996 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 40296 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 29071 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 44051 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 44161 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 49241 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 45036 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 45366 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 71096 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 46101 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 46946 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 9288 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 65551 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 69858 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 47811 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 48031 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 48116 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 51193 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 52801 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 54166 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 55731 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 45936 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 71101 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 57756 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 58531 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 33646 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 60001 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 60836 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 61561 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 45941 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 63656 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 64516 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 65483 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 65938 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 66136 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 66256 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 66576 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 67036 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 68591 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 69901 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 70561 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 71081 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 52156 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 1906 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 8081 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 9741 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 12676 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 13531 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 17906 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 21011 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 25441 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 29931 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 30696 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 34821 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 40511 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 42251 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 43196 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 45656 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 51576 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 52566 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 56681 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 58171 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 58191 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 60031 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 60896 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 63696 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu
# Lieu ID: 67171 - Nom: Inconnu
#   Manoir: Inconnu - Seigneur: Inconnu

# %%
# Exercise 4
# Now that we have a quantity of raw data, we will extract the interesting parts.
# In our case, we want to count the money paid by each manor and compare it to the number of ploughs it has.
# - Can you find the corresponding json fields?
# - Then, you can list these numbers for each manor in Derbyshire.
# - And format this in an appropriate comma-separated values (CSV) file.

import csv

def extraire_informations_et_creer_csv(details_lieux):
    with open('manoirs_derbyshire.csv', mode='w', newline='', encoding='utf-8') as fichier_csv:
        ecrivain_csv = csv.writer(fichier_csv)
        ecrivain_csv.writerow(['ID Manoir', 'Nom Manoir', 'Argent Payé', 'Nombre de Charrues'])

        for lieu in details_lieux:
            if 'manors' in lieu:
                for manoir in lieu['manors']:
                    id_manor = manoir.get('id', 'Inconnu')
                    nom_manor = manoir.get('name', 'Inconnu')
                    argent_paye = manoir.get('money_paid', 'Inconnu')
                    nombre_charrues = manoir.get('ploughs', 'Inconnu')
                    ecrivain_csv.writerow([id_manor, nom_manor, argent_paye, nombre_charrues])

details_lieux_derbyshire = recuperer_details_lieux(ids_lieux_derbyshire)
extraire_informations_et_creer_csv(details_lieux_derbyshire)

# %%
# Exercise 5
# What is the richest manor in Derbyshire?

#######################################################
################## YOUR ANSWER HERE ##################
#######################################################

# %%
# Exercise 6
# Give the total value paid by Derbyshire.

#######################################################
################## YOUR ANSWER HERE ##################
#######################################################
